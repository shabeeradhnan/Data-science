# %% [markdown]
# Sample Notebook

# %%
df = spark.read.format('csv')\
               .option('header', 'true')\
               .option('inferSchema', 'true')\
               .load('/Workspace/Users/asyedshabeeradhnan01@gmail.com/Data-science/raw/ipl_ball_by_ball.csv')

# %%
df_2 = spark.read.format('csv')\
            .option('header', 'true')\
            .option('inferSchema', 'true')\
            .load('/Workspace/Users/asyedshabeeradhnan01@gmail.com/Data-science/raw/ipl_matches.csv')

# %%
df.limit(10).display()

# %%
df_2.limit(10).display()

# %% [markdown]
# use case : (data engineering steps)
#     * recommendation sytem for finding replacement
# 1) period 2020-2026 , cap(present in all six seasons), faced atleast 100 balls, bowled atleast (50 overs) in last 6 years
# 2) batsman_model : runs_scored, balls_faced, runs_scored_in_pp, runs_scored_in_mo, runs_scored_in_Death, average, sr , dot ball %
# 3) bowler_model : overs_bowled, runs_conceded, wickets_taken, runs_conceded_in_pp, runs_conceded_in_mo, runs_conceded_in_death
# 4) all-rounder model : runs_scored, balls_faced, runs_scored_in_pp, runs_scored_in_mo, runs_scored_in_Death, overs_bowled, runs_conceded, wickets_taken, runs_conceded_in_pp, runs_conceded_in_mo
# 5) find a player details dataset

# %% [markdown]
# (machine learning steps)
# 1) Train test split
# 2) Feature engineering (column engineering)
# 3) Statistical tests
# 4) feature selection (column selection)
# 5) model selection
# 6) model evaluation
