# %% [markdown]
# # The Spark Foundation

# %% [markdown]
# # DATA SCIENCE AND BUSINESS ANALYTICS INTERNSHIP

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Name:  A SYED SHABEER ADHNAN

# %% [markdown]
# ## Task 1: Prediction using Supervised ML

# %% [markdown]
# ### Question : Predict the percentage of an student based on the no. of study hours.

# %% [markdown]
# DataSet link: http://bit.ly/w-data

# %% [markdown]
# ### Import the requried libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### Load the requried dataset

# %%
df = pd.read_csv('https://raw.githubusercontent.com/AdiPersonalWorks/Random/master/student_scores%20-%20student_scores.csv')
df
# Out:
#     Hours  Scores
# 0     2.5      21
# 1     5.1      47
# 2     3.2      27
# 3     8.5      75
# 4     3.5      30
# 5     1.5      20
# 6     9.2      88
# 7     5.5      60
# 8     8.3      81
# 9     2.7      25
# 10    7.7      85
# 11    5.9      62
# 12    4.5      41
# 13    3.3      42
# 14    1.1      17
# 15    8.9      95
# 16    2.5      30
# 17    1.9      24
# 18    6.1      67
# 19    7.4      69
# 20    2.7      30
# 21    4.8      54
# 22    3.8      35
# 23    6.9      76
# 24    7.8      86

# %% [markdown]
# ### Data visualization

# %%
plt.xlabel('Hours')
plt.ylabel('Scores')
plt.title('Scores based on study hours')
plt.scatter(df['Hours'], df['Scores'])
plt.show()

# %% [markdown]
# ### Extracting the Input and Target variables

# %%
X = df.iloc[:, :-1].values  
y = df.iloc[:, 1].values

# %% [markdown]
# ### Splitting the training and testing datasets

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %% [markdown]
# ### Creating the supervised machine learning model
# From the above data virtualization, we can clearly see that the, input(Hours) and target(Scores) are Linear in nature, So we use the LinearRegression model from sklearn library

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### Predicting the output from our trained model
#
# What is the score of the student, having the study hour of 9.25 hours?

# %%
model.predict([[9.25]])
# Out:
# array([93.69173249])

# %% [markdown]
# ### Accuracy of the model

# %%
model.score(X_test, y_test)
# Out:
# 0.9454906892105354

# %% [markdown]
# ### LinearRegression line for the model

# %%
plt.xlabel('Hours')
plt.ylabel('Scores')
plt.title('Score based on study hours')
plt.scatter(df['Hours'], df['Scores'])
plt.plot(df['Hours'], model.predict(df[['Hours']]), color = 'red')
plt.show()

# %%
y_test
# Out:
# array([20, 27, 69, 30, 62], dtype=int64)

# %%
y_pred = model.predict(X_test)
y_pred
# Out:
# array([16.88414476, 33.73226078, 75.357018  , 26.79480124, 60.49103328])

# %% [markdown]
# ### Actual output vs Predicted ouput

# %%
ans = pd.DataFrame({'Actual' : y_test, 'Predicted' : y_pred})

# %%
ans
# Out:
#    Actual  Predicted
# 0      20  16.884145
# 1      27  33.732261
# 2      69  75.357018
# 3      30  26.794801
# 4      62  60.491033
