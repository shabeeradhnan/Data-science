# %%
from pyspark.sql.functions import *
from pyspark.sql.types import *

# %%
df_matches = spark.read.format('csv')\
               .option('header', 'true')\
               .option('inferSchema', 'true')\
               .load('/Workspace/Users/asyedshabeeradhnan01@gmail.com/Data-science/raw/ipl_matches.csv')

# %%
df_eachball_info = spark.read.format('csv')\
               .option('header', 'true')\
               .option('inferSchema', 'true')\
               .load('/Workspace/Users/asyedshabeeradhnan01@gmail.com/Data-science/raw/ipl_ball_by_ball.csv')

# %%
df_period = df_eachball_info.withColumn('season', when(col('season').rlike(r"^\d{4}/\d{2}$"), year(col('date'))) 
              .otherwise(col('season')))\
              .withColumn('season', col('season').cast(IntegerType()))\
              .filter(col('season') >= 2020)

# %% [markdown]
# **Bowler_model** : overs_bowled, runs_conceded, wickets_taken, runs_conceded_in_pp, runs_conceded_in_mo, runs_conceded_in_death,runs_conceded_in_wide,runs_conceded_in_noball

# %%
df_bowler = df_period.groupBy('over','bowler').agg(count('over').alias('balls_bowled'),sum('total_runs').alias('runs_given'),sum('is_wicket').alias('wickets'),sum(when(col('is_powerplay') == 1,col('total_runs'))).alias('runs_in_po'),sum(when(col('is_middle_overs') == 1,col('total_runs'))).alias('runs_in_mo'),sum(when(col('is_death_overs') == 1,col('total_runs'))).alias('runs_in_do'),sum('wides').alias('wides'),sum('noballs').alias('noballs'))\
            .groupBy('bowler').agg(count('bowler').alias('over_bowled'),sum('runs_given').alias('runs_given'),sum('wickets').alias('wickets'),sum('runs_in_po').alias('runs_in_po'),sum('runs_in_mo').alias('runs_in_mo'),sum('runs_in_do').alias('runs_in_do'),sum('wides').alias('wides'),sum('noballs').alias('noballs')).orderBy('bowler')

# %%
df_bowler.display()
